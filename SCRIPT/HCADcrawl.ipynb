# %%
import requests
import random
import geopandas as gpd
from shapely.geometry import Polygon
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
url = "https://arcweb.hcad.org/server/rest/services/public/public_query/MapServer/0/query"

# %%
# Get all ObjectIDs
id_params = {
    "where": "1=1",
    "returnIdsOnly": "true",
    "f": "json"
}
id_response = requests.get(url, params=id_params, verify=False)
all_ids = id_response.json().get("objectIds", [])

# Sample 25 records
sample_ids = random.sample(all_ids, min(500, len(all_ids)))

# %%
## Feature Query Parameters
query_params = {
    "objectIds": ",".join(map(str, sample_ids)),
    "outFields": "*",
    "returnGeometry": "true",
    "f": "json",
    "outSR": "4326"
}

# %%
## Feature Query
query_response = requests.get(url, params=query_params, verify=False)
features = query_response.json().get("features", [])

# %%
# Step 4: Build attribute + polygon list
records = []
geometries = []

# %%
## Parsing Polygon Geometry
for feature in features:
    attrs = feature.get("attributes", {})
    rings = feature.get("geometry", {}).get("rings", [])
    try:
        if rings and isinstance(rings, list) and len(rings[0]) > 2:
            polygon = Polygon(rings[0])  # Use only outer ring for now
            records.append(attrs)
            geometries.append(polygon)
    except Exception:
        continue

# %%
# Step 5: Construct GeoDataFrame
if geometries:
    gdf = gpd.GeoDataFrame(records, geometry=geometries, crs="EPSG:4326")
else:
    raise ValueError("No valid geometries parsed from 'rings'.")

gdf.head()
# Out:
#    OBJECTID       HCAD_NUM                          owner  \
# 0       201  0432130000025  DUNHAM POINTE DEVELOPMENT LLC
# 1      1515  1475440010001                   PASADENA ISD
# 2      1716  1188880040126      WEST HARRIS COUNTY MUD 11
# 3      4544  0451750020240         RANGER II SILBER RD LP
# 4      4722  1404180010001           WASTE CORPORATION OF
#
#                              subdivision                      address  \
# 0                       CY FAIR WEST M/R  0 NORTHWEST (OFF) FWY # OFF
# 1                        STRAWBERRY ROAD             2707 LAFFERTY RD
# 2                   WESTBRIDGE SEC 1 & 2              0 WESTWILLOW DR
# 3  NORTH POST OAK INDUSTRIAL II - ISD 01               1200 SILBER RD
# 4          BEECHNUT / BISSONNET INT COMM               14515 AUTO PKY
#
#        city    zip parcel_type state_class    appr_val     mkt_val  \
# 0   CYPRESS  77433        None          D2         NaN         NaN
# 1  PASADENA  77502        None          XV         NaN         NaN
# 2   HOUSTON  77064        None          XV         0.0         0.0
# 3   HOUSTON  77055        None          F1  11688911.0  11688911.0
# 4   HOUSTON  77083        None          F1   2098311.0   2098311.0
#
#    Shape.STArea()  Shape.STLength()  \
# 0    4.084331e+06       9670.951613
# 1    4.190712e+05       2680.226530
# 2    4.097926e+05       2791.531547
# 3    3.726110e+05       2749.382610
# 4    3.710803e+05       2710.194283
#
#                                          legal_lines  \
# 0                            TR 4|ABST 547 J W MOODY
# 1  RES A BLK 1|(SCHOOL & RELATED USES)|PASADENA I...
# 2                       RES A BLK 4|WESTBRIDGE SEC 2
# 3                          TR 30A|ABST 871 J WHARTON
# 4                         RES A BLK 1|MILLWORK SEC 2
#
#                                             geometry
# 0  POLYGON ((-95.72775 29.98211, -95.72762 29.982...
# 1  POLYGON ((-95.19551 29.67214, -95.19548 29.670...
# 2  POLYGON ((-95.5527 29.89793, -95.55263 29.8979...
# 3  POLYGON ((-95.46176 29.79129, -95.46493 29.791...
# 4  POLYGON ((-95.63818 29.6861, -95.63843 29.6860...

# %%
# Load METRO MTA service area once
metro_gdf = gpd.read_file("..\REF\Metro_MTA_Tax_Area.geojson").to_crs(epsg=4326)
metro_union = metro_gdf.union_all()

# Container to hold unique intersecting records
final_records = []
final_geometries = []
used_ids = set()
target_count = 1000
batch_size = 500
max_attempts = 20  # avoid infinite loops

# %%
# resampling logic
def fetch_and_filter(batch_size=500):
    remaining_ids = list(set(all_ids) - used_ids)
    if len(remaining_ids) == 0:
        return

    sample_ids = random.sample(remaining_ids, min(batch_size, len(remaining_ids)))

    query_params = {
        "objectIds": ",".join(map(str, sample_ids)),
        "outFields": "*",
        "returnGeometry": "true",
        "f": "json",
        "outSR": "4326"
    }

    response = requests.get(url, params=query_params, verify=False)
    features = response.json().get("features", [])

    for feature in features:
        oid = feature.get("attributes", {}).get("OBJECTID")
        if oid in used_ids:
            continue

        rings = feature.get("geometry", {}).get("rings", [])
        if rings and isinstance(rings, list) and len(rings[0]) > 2:
            try:
                polygon = Polygon(rings[0])
                if polygon.intersects(metro_union):
                    final_records.append(feature["attributes"])
                    final_geometries.append(polygon)
                    used_ids.add(oid)
            except Exception:
                continue

# %%
attempts = 0
while len(final_records) < target_count and attempts < max_attempts:
    fetch_and_filter(batch_size)
    attempts += 1
    print(f"Collected {len(final_records)} valid records (attempt {attempts})")
# Out:
# Collected 402 valid records (attempt 1)
# Collected 804 valid records (attempt 2)
# Collected 1213 valid records (attempt 3)

# %%
final_gdf = gpd.GeoDataFrame(final_records, geometry=final_geometries, crs="EPSG:4326")

# %% [markdown]
# # MAP
# Randomly Selected HCAD Parcels within METRO Service Area

# %%
import folium
from folium import GeoJson

# %%
m = folium.Map(location=[29.76, -95.37], zoom_start=11, tiles="cartodbpositron")

for _, row in final_gdf.iterrows():
    sim_geo = gpd.GeoSeries([row.geometry]).__geo_interface__
    folium.GeoJson(sim_geo).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8263703d4f12d862e9f110bd60a37ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8263703d4f12d862e9f110bd60a37ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8263703d4f12d862e9f110bd60a37ef = L.map(
#                 &quot;map_c8263703d4f12d862e9f110bd60a37ef&quot;,
#                 {
#                     center: [29.76, -95.37],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4717beb5ac778140a9403d1fe712bb8 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4717beb5ac778140a9403d1fe712bb8.addTo(map_c8263703d4f12d862e9f110bd60a37ef);
#
#
#
#         function geo_json_0b52897a09a0a2b6dc029e0b358883ab_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0b52897a09a0a2b6dc029e0b358883ab = L.geoJson(null, {
#                 onEachFeature: geo_json_0b52897a09a0a2b6dc029e0b358883ab_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_0b52897a09a0a2b6dc029e0b358883ab_add (data) {
#             geo_json_0b52897a09a0a2b6dc029e0b358883ab
#                 .addData(data);
#         }
#             geo_json_0b52897a09a0a2b6dc029e0b358883ab_add({&quot;bbox&quot;: [-95.22785955041923, 29.609657809901915, -95.22764214087944, 29.610024251907056], &quot;features&quot;: [{&quot;bbox&quot;: [-95.22785955041923, 29.609657809901915, -95.22764214087944, 29.610024251907056], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-95.22764214087944, 29.609857719549808], [-95.22785955041923, 29.609657809901915], [-95.22783216554333, 29.610024251907056], [-95.22764214087944, 29.609857719549808]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_0b52897a09a0a2b6dc029e0b358883ab.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_0b52897a09a0a2b6dc029e0b358883ab.addTo(map_c8263703d4f12d862e9f110bd60a37ef);
#
#
#
#         function geo_json_a78de0877c5790ff34a26d1027d4d913_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a78de0877c5790ff34a26d1027d4d913 = L.geoJson(null, {
#                 onEachFeature: geo_json_a78de0877c5790ff34a26d1027d4d913_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_a78de0877c5790ff34a26d1027d4d913_add (data) {
#             geo_json_a78de0877c5790ff34a26d1027d4d913
#                 .addData(data);
#         }
#             geo_json_a78de0877c5790ff34a26d1027d4d913_add({&quot;bbox&quot;: [-95.22785955041923, 29.609657809901915, -95.22764214087944, 29.610024251907056], &quot;features&quot;: [{&quot;bbox&quot;: [-95.22785955041923, 29.609657809901915, -95.22764214087944, 29.610024251907056], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-95.22764214087944, 29.609857719549808], [-95.22785955041923, 29.609657809901915], [-95.22783216554333, 29.610024251907056], [-95.22764214087944, 29.609857719549808]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_a78de0877c5790ff34a26d1027d4d913.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_a78de0877c5790ff34a26d1027d4d913.addTo(map_c8263703d4f12d862e9f110bd60a37ef);
#
#
#
#         function geo_json_91f9446bda66a15895f55b90f7e8a1cd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_91f9446bda66a15895f55b90f7e8a1cd = L.geoJson(null, {
#                 onEachFeature: geo_json_91f9446bda66a15895f55b90f7e8a1cd_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_91f9446bda66a15895f55b90f7e8a1cd_add (data) {
#             geo_json_91f9446bda66a15895f55b90f7e8a1cd
#                 .addData(data);
#         }
#             geo_json_91f9446bda66a15895f55b90f7e8a1cd_add({&quot;bbox&quot;: [-95.60055692095574, 30.01050706160911, -95.59915282735741, 30.012750329730927], &quot;features&quot;: [{&quot;bbox&quot;: [-95.60055692095574, 30.01050706160911, -95.59915282735741, 30.012750329730927], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-95.6005269005687, 30.010507335016513], [-95.6005400997404, 30.01050706160911], [-95.60054066264456, 30.01058113204373], [-95.60055673137721, 30.012695702028935], [-95.60055692095574, 30.01272069635967], [-95.59916114500525, 30.012750329730927], [-95.59

# %% [markdown]
# # Exporting to geojson

# %%
from datetime import datetime
import os
import json

# %%
# Ensure OUTPUT directory exists
os.makedirs("OUTPUT", exist_ok=True)

# %%
# Metadata
metadata = {
    "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "sampling_batch_size": batch_size,
    "total_properties_sampled": len(final_gdf)
}

# %%
# File naming
timestamp_str = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"metro_intersecting_parcels_{timestamp_str}.geojson"
filepath = os.path.join("OUTPUT", filename)

# %%
# Save GeoJSON with metadata in a FeatureCollection
geojson_obj = json.loads(final_gdf.to_json())
geojson_obj["metadata"] = metadata

# Write to file
with open(filepath, "w") as f:
    json.dump(geojson_obj, f)

print(f"✅ GeoJSON exported to: {filepath}")
# Out:
# ✅ GeoJSON exported to: OUTPUT\metro_intersecting_parcels_20250505_220658.geojson

# %%
import pandas as pd

# %%
# Extract HCAD_NUM values
hcad_df = final_gdf[["HCAD_NUM"]].copy()
hcad_df["timestamp"] = metadata["timestamp"]
hcad_df["sampling_batch_size"] = metadata["sampling_batch_size"]
hcad_df["total_properties_sampled"] = metadata["total_properties_sampled"]

# Define CSV path
csv_filename = f"metro_intersecting_parcels_HCAD_{timestamp_str}.csv"
csv_path = os.path.join("OUTPUT", csv_filename)

# Export to CSV
hcad_df.to_csv(csv_path, index=False)

print(f"✅ HCAD_NUM list exported to: {csv_path}")
# Out:
# ✅ HCAD_NUM list exported to: OUTPUT\metro_intersecting_parcels_HCAD_20250505_220658.csv

# %% [markdown]
# # Real Property
